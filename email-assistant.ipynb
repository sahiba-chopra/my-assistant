# %%
import autogen

config_list = [{
    "model":"mistral-small",
    "base_url":'http://localhost:11434/v1',
    "api_key":"ollama"
}]

llm_config = {
    # "request_timeout":800,
    "config_list":config_list
}

# %%
import os
import pickle
# Gmail API utils
from googleapiclient.discovery import build
from google_auth_oauthlib.flow import InstalledAppFlow
from google.auth.transport.requests import Request
# for encoding/decoding messages in base64
from base64 import urlsafe_b64decode, urlsafe_b64encode
# for dealing with attachement MIME types
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart
from email.mime.image import MIMEImage
from email.mime.audio import MIMEAudio
from email.mime.base import MIMEBase
from mimetypes import guess_type as guess_mime_type

# Request all access (permission to read/send/receive emails, manage the inbox, and more)
SCOPES = ['https://mail.google.com/']
your_email = input("Enter your email: ")

# %%
def gmail_authenticate():
    creds = None
    # the file token.pickle stores the user's access and refresh tokens, and is
    # created automatically when the authorization flow completes for the first time
    if os.path.exists("token.pickle"):
        with open("token.pickle", "rb") as token:
            creds = pickle.load(token)
    # if there are no (valid) credentials availablle, let the user log in.
    if not creds or not creds.valid:
        if creds and creds.expired and creds.refresh_token:
            creds.refresh(Request())
        else:
            flow = InstalledAppFlow.from_client_secrets_file('credentials.json', SCOPES)
            creds = flow.run_local_server(port=0)
        # save the credentials for the next run
        with open("token.pickle", "wb") as token:
            pickle.dump(creds, token)
    return build('gmail', 'v1', credentials=creds)

# get the Gmail API service
service = gmail_authenticate()

# %%
def search_messages(service, query):
    result = service.users().messages().list(userId='me',q=query).execute()
    messages = [ ]
    if 'messages' in result:
        messages.extend(result['messages'])
    while 'nextPageToken' in result:
        page_token = result['nextPageToken']
        result = service.users().messages().list(userId='me',q=query, pageToken=page_token).execute()
        if 'messages' in result:
            messages.extend(result['messages'])
    return messages

# %%
# utility functions
def get_size_format(b, factor=1024, suffix="B"):
    """
    Scale bytes to its proper byte format
    e.g:
        1253656 => '1.20MB'
        1253656678 => '1.17GB'
    """
    for unit in ["", "K", "M", "G", "T", "P", "E", "Z"]:
        if b < factor:
            return f"{b:.2f}{unit}{suffix}"
        b /= factor
    return f"{b:.2f}Y{suffix}"

def clean(text):
    # clean text for creating a folder
    return "".join(c if c.isalnum() else "_" for c in text)

# %%
def parse_parts(service, parts, folder_name, message):
    """
    Utility function that parses the content of an email partition
    """
    if parts:
        for part in parts:
            filename = part.get("filename")
            mimeType = part.get("mimeType")
            body = part.get("body")
            data = body.get("data")
            # file_size = body.get("size")
            # part_headers = part.get("headers")
            if part.get("parts"):
                # recursively call this function when we see that a part
                # has parts inside
                parse_parts(service, part.get("parts"), folder_name, message)
            if mimeType == "text/plain":
                # if the email part is text plain
                if data:
                    text = urlsafe_b64decode(data).decode()
                    print(text)
            # elif mimeType == "text/html":
            #     # if the email part is an HTML content
            #     # save the HTML file and optionally open it in the browser
            #     if not filename:
            #         filename = "index.html"
            #     filepath = os.path.join(folder_name, filename)
            #     print("Saving HTML to", filepath)
            #     with open(filepath, "wb") as f:
            #         f.write(urlsafe_b64decode(data))
            # else:
            #     # attachment other than a plain text or HTML
            #     for part_header in part_headers:
            #         part_header_name = part_header.get("name")
            #         part_header_value = part_header.get("value")
            #         if part_header_name == "Content-Disposition":
            #             if "attachment" in part_header_value:
            #                 # we get the attachment ID 
            #                 # and make another request to get the attachment itself
            #                 print("Saving the file:", filename, "size:", get_size_format(file_size))
            #                 attachment_id = body.get("attachmentId")
            #                 attachment = service.users().messages() \
            #                             .attachments().get(id=attachment_id, userId='me', messageId=message['id']).execute()
            #                 data = attachment.get("data")
            #                 filepath = os.path.join(folder_name, filename)
            #                 if data:
            #                     with open(filepath, "wb") as f:
            #                         f.write(urlsafe_b64decode(data))

# %%
def read_message(service, message):
    """
    This function takes Gmail API `service` and the given `message_id` and does the following:
        - Downloads the content of the email
        - Prints email basic information (To, From, Subject & Date) and plain/text parts
    """
    msg = service.users().messages().get(userId='me', id=message['id'], format='full').execute()
    # parts can be the message body, or attachments
    payload = msg['payload']
    headers = payload.get("headers")
    parts = payload.get("parts")
    folder_name = "email"
    has_subject = False
    if headers:
        # this section prints email basic info & creates a folder for the email
        for header in headers:
            name = header.get("name")
            value = header.get("value")
            if name.lower() == 'from':
                # we print the From address
                print("From:", value)
            if name.lower() == "to":
                # we print the To address
                print("To:", value)
            if name.lower() == "subject":
            #     # make our boolean True, the email has "subject"
            #     has_subject = True
            #     # make a directory with the name of the subject
                # folder_name = clean(value)
            #     # we will also handle emails with the same subject name
            #     folder_counter = 0
            #     while os.path.isdir(folder_name):
            #         folder_counter += 1
            #         # we have the same folder name, add a number next to it
            #         if folder_name[-1].isdigit() and folder_name[-2] == "_":
            #             folder_name = f"{folder_name[:-2]}_{folder_counter}"
            #         elif folder_name[-2:].isdigit() and folder_name[-3] == "_":
            #             folder_name = f"{folder_name[:-3]}_{folder_counter}"
            #         else:
            #             folder_name = f"{folder_name}_{folder_counter}"
            #     os.mkdir(folder_name)
                print("Subject:", value)
            if name.lower() == "date":
                # we print the date when the message was sent
                print("Date:", value)
    if not has_subject:
        # if the email does not have a subject, then make a folder with "email" name
        # since folders are created based on subjects
        # if not os.path.isdir(folder_name):
        #     os.mkdir(folder_name)
        pass
    parse_parts(service, parts, folder_name, message)
    print("="*50)

# %%
results = search_messages(service, 'from: CVS')

# %%
for msg in results:
    read_message(service, msg)
# Out:
# From: CVS Pharmacy <info@alerts.cvs.com>
# To: <ericbzhou0513@gmail.com>
# Subject: With CVS, You're One step closer to a Better Tomorrow!
# Date: Fri, 04 Oct 2024 09:39:30 -0600
#
#
# Thank you for trusting CVS(R) to be with you for this journey.
#
# HTTPGetWrap|https://www.cvs.com/pharmacy/v2/?DisableWebtrends=Y&DisableBluecore=Y#/pharmacy&cid=em_postcovax_thankyou_top_banner
# Helping bring you one step closer to a healthier tomorrow.
#
# HTTPGetWrap|https://www.cvs.com/pharmacy/v2/?Desktop-image=Trigger1_Hero Image Border Module_1_Dk_Mb.jpg#/pharmacy
#
# We&rsquo;re honored that you came to CVS(R) for your vaccination.
#
# Congratulations on being one step closer to a healthier future.
#
# It means so much to all of us
# at CVS that you trusted us as
# a partner
# on your health care journey.
#
# &zwnj;
#
# We&rsquo;re here to support you by offering easy and safe ways to keep
# ? you on the path to better health. Whether it&rsquo;s an allergy
# or an earache,
# a telehealth visit
# or same-day delivery of a new prescription,
# we&rsquo;re ready to help meet your everyday health needs.
#
# &zwnj;
#
# With best wishes
# from all of us at CVS.
#
# HTTPGetWrap|http://www.cvs.com/pharmacy?cid=em_postcovax_thankyou_learn_about_cvs
# Learn more about CVS
#
# Need your vaccination record?
#
# View your CVS Pharmacy(R) vaccination records* in your health dashboard. You must be 18 or older to access.
#
# HTTPGetWrap|https://www.cvscare.com/login/?scope=openid%20profile%20address&oidcserver=https:%2F%2Fapi.cvshealth.com%2Fretail%2Foauth2%2Fv2%2Fauthorize&sessionid=f4963157-34ff-467e-b56a-5380a818a1ce&state=e3411fba-c14f-4b97-8118-abbd6a95f797&cid=em_postcovax_thankyou_vaccination_records
# View your vaccination records >
#
# Wellness, and more, coming your way.
#
# I'm one step closer to hugging my grandchild.
#
# With every COVID-19 vaccination, we get one step closer to a better tomorrow. Share on social media what
#
# you can't wait to be #OneStepCloser to.
#
# HTTPGetWrap|https://www.youtube.com/watch?v=YJVADOSdY6c&t=5s&cid=em_postcovax_thankyou_about_the_vaccine
# Learn about the vaccine >
#
# Helping you stay informed
#
# Keep an eye out for our emails &#8212; we'll be sharing
# all the ways we can provide you services and
# hands-on support.
#
#
#
#
#
#
#
#
#
# Having trouble viewing this email?
#
# HTTPGetWrap|https://www.cvs.com/pharmacy
# View online?
#
#
#
#
#
# View our
# HTTPGetWrap|https://www.cvs.com/help/privacy_policy.jsp
# privacy policy .
#
#
#
# If you no longer wish to receive future emails from us, you can
# HTTPGetWrap|https://www.cvs.com/email-campaign-optout-unsubscribe?opptyID=aq0Bg1727973500877&campaignName=IMZGenericEmail-1-DAY
# unsubscribe .
#
#
#
# Please do not reply to this email. For questions unrelated to your email preferences, contact us by calling 1-800-746-7287 or through our
# HTTPGetWrap|https://www.cvs.com/help/help_index.jsp
# Customer Service page .
#
# (c) 2021 CVS Pharmacy, Inc.
#
# One CVS Drive, Woonsocket, RI 02895
#
# *FOR VACCINATION RECORDS: Your vaccination record summaries may not include complete information or serve as proof of vaccination in some states. If you gave contact information for your primary care provider, they&rsquo;ll have a record of your vaccinations. Some states may also keep a record. You may also call CVS Pharmacy(R) to request a copy or ask questions.
#
# &zwnj;
#
# &zwnj;
#
# &zwnj;
#
#
#
#
# ==================================================
# From: CVS Pharmacy <cvspharmacy@alerts.cvs.com>
# To: <ericbzhou0513@gmail.com>
# Subject: A new vaccination record is available
# Date: Thu, 03 Oct 2024 11:44:25 -0600
#
#
#
#
#
#  Post Notification Email
#
#
#  https://click.em.cvs.com/?qs=1b925ad57a7d8f9f3e8c0c55b87886cf1edbb627ee2b9f86e662e0579240d3a4ed48d531cedb607828e5be0dc339db5080db8e04343e25c1bf04a2bd4c70a61a
#
#
#
#
#
# You have a new vaccination record
#
#
#
#  Hi ERIC,
#
#
#
#
#
#
#
#
#  You have a new vaccination record on your health dashboard.
#
#
# https://click.em.cvs.com/?qs=1b925ad57a7d8f9f2030eace526074918ee7126ab2327ccb6734ef0a6f226df6926cebbf53acebf3fba89c23f25a86f56b10830871516f6de52bd06d0e2ac1a1
# Get vaccination record &#8250;
#
#
#
#
#  Add vaccinations from another provider
#
#  Received a vaccination somewhere else? Add it to your records to keep all your information in one place.
#
# https://click.em.cvs.com/?qs=1b925ad57a7d8f9ff6101c3f20e6b86b2f9cc5373736aba2326def070fc86917b24341c5802e1c72511811f29cfc02e5a83cde5352c6a36b46ae4f5102052d83
# Add a vaccination record &#8250;
#
#
#
#
#
#  About your health dashboard
#
#
#
#
# 	-
#
#
# https://click.em.cvs.com/?qs=1b925ad57a7d8f9f3bfe1908b165ecf03ca57d17c0dd7cb7c6b45d6e5ffb909692561390366fec79a76b52000e380afbeff0c7bfa97ef0092953dc2d21d48ab1
# Sign in to your health dashboard &#8250;
#
#
#
#  How are we doing?
#
#  Take a quick survey to help us improve health care visits.
#
# https://click.em.cvs.com/?qs=1b925ad57a7d8f9ffa7d67f5c79a3b04c58a36f56f815eff90fe0463e98993617edce8264e454abe5303208c34cb8a98e3d4049f91815d08dc2784d81165fe1d
# Take the survey &#8250;
#
#
#
#
#
#  https://click.em.cvs.com/?qs=1b925ad57a7d8f9f3e8c0c55b87886cf1edbb627ee2b9f86e662e0579240d3a4ed48d531cedb607828e5be0dc339db5080db8e04343e25c1bf04a2bd4c70a61a
#
# (c) 2024 CVS Pharmacy, Inc.
#
#  One CVS Drive, Woonsocket, RI 02895
#
#
#  Add cvspharmacy@alerts.cvs.com to your address book to continue receiving our emails.
#
#
#  You&rsquo;re receiving this email as part of an interaction you had with CVS Pharmacy(R).
#
#
#  View thehttps://click.em.cvs.com/?qs=1b925ad57a7d8f9fbe4c945e8a74d8dd67917d0120a9092916681d068174013c443def5c756352f57b544ea412ed5f6577783e6a20f3297c2cb11c014ef45b6b
# CVS Pharmacy Notice of Privacy Practices .
#
#
#
#
#
# ==================================================
# From: CVS Pharmacy <cvspharmacy@alerts.cvs.com>
# To: <ericbzhou0513@gmail.com>
# Subject: Your vaccination record
# Date: Thu, 03 Oct 2024 10:38:45 -0600
#
#  https://click.em.cvs.com/?qs=0f2d007e6c87a14f239c033e1973eef168cbca1e43d5860cbd30674a0b7b5413f4d9aa44ce081e371dea035fb7ad4d5b2c9485a8f46c2b1a2a981457a87e5db9
#
#
#
#
# You have a new vaccination record
#
#
#
#
#  Hi Eric,
#
#
#
#
#
#  Thanks for choosing CVS Pharmacy® for your vaccination.
#
#
#  Keep this email for details about the vaccination(s) you got on October 3, 2024.
#
#
#  If you’re 18 or older, you’ll receive another email when this record is available on your health dashboard.
#
#
#
#  View a minor’s health records
#
#
#
#
#  <p>If you’ve added a minor to your health dashboard, you can find this record there once it’s available.</p>To add a minor, visit your pharmacy dashboard.
#
#
# https://click.em.cvs.com/?qs=0f2d007e6c87a14f87988ea26830d25b9e4a8c9ee8b5ea10527efa540e9de0657c9c16bc17366a5642a36c2a08cd76864d503d9c564c265a9fa7ec6ca45ab3de
# Sign in to your pharmacy dashboard &#8250;
#
#
#
#
#
#
#
#  Appointment details
#
#
#  Who
#
#  Eric Z.
#
#
#  When
#
#
#
#
#
#  Where
#
#
#
#  ,
#
#
#
#
#
#
#  How was your experience?
#
#  Take a quick survey to help us improve health care visits.
#
# https://click.em.cvs.com/?qs=0f2d007e6c87a14fade37a824d60cea19f9a4017cd6845ec78cd9965075a1c8380e8dac81ba68961647b76ac23968ae5e82df539227e186265b813287b5615fb
# Take the survey &#8250;
#
#
#
#
#  https://click.em.cvs.com/?qs=0f2d007e6c87a14f239c033e1973eef168cbca1e43d5860cbd30674a0b7b5413f4d9aa44ce081e371dea035fb7ad4d5b2c9485a8f46c2b1a2a981457a87e5db9
#
# (c) 2024 CVS Pharmacy(R), Inc.
#
#  One CVS Drive, Woonsocket, RI 02895
#
#
#  Add cvspharmacy@alerts.cvs.com to your address book to continue receiving our emails.
#
#
#  This email is for your planned appointment. It will not be saved or used for purposes other than notifications related to your care.
#
#
#  View our
# https://click.em.cvs.com/?qs=0f2d007e6c87a14f9b1ed4a45ce4e290c311e124a2cc84f93f6dc3ad506d45d24c9cca8ab7168165b53ca1ffd57845248165ef2f22c8cb1969715c6096a4e289
# Notice of Privacy Practices .
#
#
#
# ==================================================
# From: CVS Pharmacy <cvspharmacy@alerts.cvs.com>
# To: <ericbzhou0513@gmail.com>
# Subject: Your CVS Pharmacy appointment is today at 12:45 PM
# Date: Thu, 03 Oct 2024 09:16:56 -0600
#
#
#
#
#
#  https://click.em.cvs.com/?qs=1b6969cdeb3b135c2747bd1c877eb60215cdd7ac1bea2f3e5a92eba4400cb1a6fa21c9238062f6ca6e692b746d06a612a713b0085728f0885ef3e458978a17f1
#
#
#
#
# We’ll see you soon
#
#
#
#
#  Hi Eric,
#
#
#
#
#
#  We’re looking forward to seeing you.
#
#
#  Please arrive 5 minutes before your scheduled appointment. If you arrive late, we may not be able to see you immediately.
#
#
#  When you arrive, follow the link to check in. Then go to the pharmacy counter or follow any signs for vaccinations. Don’t go to the MinuteClinic® waiting area.
#
#
#   Check in
#
#
#
#
#
#  Appointment details
#
#
#  Who
#
#  Eric Z.
#
#  Vaccine(s)
#
#  <p>Flu (Inactivated)</p>
#
#
#
#
#  When
#
#    Thursday, October 3,
#
#   at 12:45 PM ET
#
#  Where
#
#  CVS Pharmacy® counter (inside CVS)
#
#    188 Linden St.
#
#  Wellesley, MA 02482
#
#
#
#  Need to change anything?
#
#
#
# https://click.em.cvs.com/?qs=1b6969cdeb3b135c17e289f145115a7cb767cde1420f16a776778e15fc61551f3cb0f1e23f9a9c198820117464c7ec918c434afdfdcdd48e971ca9781d693e1f
# Manage this appointment &#8250;
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  https://click.em.cvs.com/?qs=1b6969cdeb3b135c2747bd1c877eb60215cdd7ac1bea2f3e5a92eba4400cb1a6fa21c9238062f6ca6e692b746d06a612a713b0085728f0885ef3e458978a17f1
#
# (c) 2024 CVS Pharmacy(R), Inc.
#
#  One CVS Drive, Woonsocket, RI 02895
#
#
#  Add cvspharmacy@alerts.cvs.com to your address book to continue receiving our emails.
#
#
#  This email is for your planned appointment. It will not be saved or used for purposes other than notifications related to your care.
#
#
#  View our
# https://click.em.cvs.com/?qs=1b6969cdeb3b135c0385071c7e81f59c3967c5f5df4b40d85c323d6ef51d4737f0a3d89e0be3987268ab405c43cec76b202247f8ceacc38705b7364e7a6329ec
# Notice of Privacy Practices .
#
#
#
# ==================================================
# From: CVS Pharmacy <cvspharmacy@alerts.cvs.com>
# To: <ericbzhou0513@gmail.com>
# Subject: Confirmed: your CVS Pharmacy appointment
# Date: Tue, 01 Oct 2024 19:15:29 -0600
#
#
#
#
#
#  https://click.em.cvs.com/?qs=13cacf5fd3c77adfb12e8fd8333242a60ca4c6332a4906cb59efb6dce7d196ae1f70e12c131fef4f3bd8662190e862d1f2a00423be22f41b4fdce5c0a2ffd343
#
#
#
#
# Your appointment is scheduled
#
#
#
#
#  Hi Eric,
#
#
#
#
#
#  We look forward to seeing you for your appointment.
#
#
#
#
#
#  Appointment details
#
#
#  Who
#
#  Eric Z.
#
#  Vaccine(s)
#
#  <p>Flu (Inactivated)</p>
#
#
#
#
#  When
#
#    Thursday, October 3,
#
#   at 12:45 PM ET
#
#  Where
#
#  CVS Pharmacy® counter (inside CVS)
#
#    188 Linden St.
#
#  Wellesley, MA 02482
#
#
#
#  Need to change anything?
#
#
#
# https://click.em.cvs.com/?qs=13cacf5fd3c77adfb4900d709704e07e10998265c73ab034377988ca161436695f8864b875a074689574f12c752359c13463e2020bed81f1f29b9c3d6b600d84
# Manage this appointment &#8250;
#
#
#
#  Add this appointment to your calendar
# 	-
# https://click.em.cvs.com/?qs=13cacf5fd3c77adfedb1f2ba5325500bb9be140ecfc28ce983408e7879da678b134955cadbe1de8133dc9b35ce51a70f9d3a65a07506f54bada7bfeb9f0dc99d
#  Add to Apple Calendar  &#8250;
# 	-
# https://click.em.cvs.com/?qs=13cacf5fd3c77adf68c798796f0e9d3c5cb52c5cd8b0e9deb2d241072868c09b0744a85d7278cfb7d0175a4d0f8c8d3db50184ebe3ffff305f8b13a62e0a1c41
#  Add to Google Calendar  &#8250;
# 	-
# https://click.em.cvs.com/?qs=13cacf5fd3c77adf23b801a612823f9854c30adf086ebe4b95f0a9b53c3133a03f8a398d712683820a6e8ff3bd221c53ed87917f484faacf9ea948fb185f66c6
#  Add to Outlook Calendar  &#8250;
#
#
#
# What to bring
#
# For your appointment, please bring the following items:
#
#
# 	-
#  Health insurance card (if you’re using insurance), voucher or other coverage
# 	-
#  Proof of identity (driver's license or state ID)
# 	-
#  Mobile phone
#
#
#
#  	On the day of your appointment
# 	1.
#
#
#
#
#
# Review information about your vaccine(s)
#
#
#
#
#
#
#  How did it go?
#
#  Thanks for setting up your appointment with us. We'd love to know how it went. By taking our short survey, you'll help us make setting up visits a better experience for everyone we serve.
#
# https://click.em.cvs.com/?qs=13cacf5fd3c77adf97fc6f563df2a6969f8f571d39b4c50077e7c235e8aeac8172585fe96507875eb25eac30d045b7bee3271c814881288dda11844a86cf38b7
# Take the survey &#8250;
#
#
#
#
#  https://click.em.cvs.com/?qs=13cacf5fd3c77adfb12e8fd8333242a60ca4c6332a4906cb59efb6dce7d196ae1f70e12c131fef4f3bd8662190e862d1f2a00423be22f41b4fdce5c0a2ffd343
#
# (c) 2024 CVS Pharmacy(R), Inc.
#
#  One CVS Drive, Woonsocket, RI 02895
#
#
#  Add cvspharmacy@alerts.cvs.com to your address book to continue receiving our emails.
#
#
#  This email is for your planned appointment. It will not be saved or used for purposes other than notifications related to your care.
#
#
#  View our
# https://click.em.cvs.com/?qs=13cacf5fd3c77adfee34c6917fa5116a5b61bb7cfd6e7de4a5659a129471e84b9e9b9aab4f40af5a99e71bf48e11e80efb24a290f01be0793a6775c7ee665bdc
# Notice of Privacy Practices .
#
#
#
# ==================================================
# To: ericbzhou0513@gmail.com
# Date: Sat, 07 Oct 2023 15:17:29 +0000
# Subject: Your vaccination record is available
# From: CVS Care <no-reply@e.care.cvs.com>
# CVS logo
# ( https://click.e.care.cvs.com/f/a/l4p0zS_3EdPJbgnVLTFuXg~~/AAQRxQA~/RgRnA_uJP0QUaHR0cHM6Ly9jYXJlLmN2cy5jb21XA3NwY0IKZSCJdiFlRfq-rVIXZXJpY2J6aG91MDUxM0BnbWFpbC5jb21YBAAAAHE~ )
#
# ************************************
# Your vaccination record is available
# ************************************
#
# Hello ERIC,
#
# Thanks for trusting us with your care. A new vaccination record
# is available on your health dashboard.
#
# ------------------
# How to view record
# ------------------
#
# * Sign in to your health dashboard.
# * Go to the Health Records section and select Vaccinations.
# * Select the vaccination record and review its details.
# Sign in to health dashboard
# ( https://click.e.care.cvs.com/f/a/TPNIk6hx3gA2nG4QT0eA7g~~/AAQRxQA~/RgRnA_uJP0RHaHR0cHM6Ly9jYXJlLmN2cy5jb20vY2FyZS1uYXZpZ2F0aW9uLyMvZW1haWwtcmVkaXJlY3Q_Zmxvdz12YWNjaW5hdGlvbnNXA3NwY0IKZSCJdiFlRfq-rVIXZXJpY2J6aG91MDUxM0BnbWFpbC5jb21YBAAAAHE~ )
#             .about-health-dashboard { color: #262626;
# margin-top: 12px; margin-bottom: 12px font-family: CVS Health
# Sans, Helvetica, Arial, Sans-Serif; line-height: 24px; font-size:
# 16px; } .about-health-dashboard .title { font-size: 18px;
# margin-top: 0px; margin-bottom: 12px; } .about-health-dashboard
# .description { font-size: 16px; line-height: 24px; margin: 0px; }
# .about-health-dashboard .list { margin-bottom: 12px; }
# .about-health-dashboard .list-item { display: flex; flex: 1 0
# auto; align-items: center; gap: 8px; margin-top: 24px;
# margin-bottom: 24px; } .about-health-dashboard .list-item-icon {
# width: 60px; height: 60px; } .about-health-dashboard
# .list-item-text { margin: 0; font-size: 16px; line-height: 24px }
#
# ----------------------
# About health dashboard
# ----------------------
#
# Health dashboard is a hub for your CVS® health records and care
# options.
#
# Pill bottle icon View test results, vaccination records and
# health information.
#
# Doctor icon Keep up with appointments and prescriptions.
#
# Calendar icon Get preventive care reminders.
#
# -----------------
# How are we doing?
# -----------------
#
# Take a quick survey
# ( https://click.e.care.cvs.com/f/a/Obp-_r76GD1T8rk8vkv1ug~~/AAQRxQA~/RgRnA_uJP0Q4aHR0cHM6Ly9zdXJ2ZXkubWVkYWxsaWEuY29tLz9jdnMtaDRsLW1lc3NhZ2luZyZlbWFpbD12YXhXA3NwY0IKZSCJdiFlRfq-rVIXZXJpY2J6aG91MDUxM0BnbWFpbC5jb21YBAAAAHE~ )
#  to help us improve health care visits.
#
# ul li { display: inline-block; list-style:none
# !important; } ul { list-style-type: none; padding-left: 0;
# margin-top: 12px; margin-bottom: 0; }
# Notices of privacy practices * MinuteClinic notice
# ( https://click.e.care.cvs.com/f/a/OEEqyTlVdFIJqhVbS0Iw5g~~/AAQRxQA~/RgRnA_uJP0RUaHR0cHM6Ly93d3cuY3ZzLmNvbS9ocy1zdGF0aWMtY29udGVudC9tY19wZGYvbWludXRlLWNsaW5pYy1oaXBhYS1Ob3ZlbWJlci04LTIwMjEucGRmVwNzcGNCCmUgiXYhZUX6vq1SF2VyaWNiemhvdTA1MTNAZ21haWwuY29tWAQAAABx )
#
# |* CVS Pharmacy notice
# ( https://click.e.care.cvs.com/f/a/fDO_A0FmTRs4Vz3KI1jRKA~~/AAQRxQA~/RgRnA_uJP0QraHR0cHM6Ly93d3cuY3ZzLmNvbS9jb250ZW50L3BhdGllbnQtcHJpdmFjeVcDc3BjQgplIIl2IWVF-r6tUhdlcmljYnpob3UwNTEzQGdtYWlsLmNvbVgEAAAAcQ~~ )
# |* CVS Healthcare Practices notice
# ( https://click.e.care.cvs.com/f/a/gPZgkinDrLHyg2NN-4yV-w~~/AAQRxQA~/RgRnA_uJP0RDaHR0cHM6Ly93d3cuY3ZzLmNvbS9jb250ZW50L2N2c2hlYWx0aGNhcmUtcHJhY3RpY2VzLXBhdGllbnQtcHJpdmFjeVcDc3BjQgplIIl2IWVF-r6tUhdlcmljYnpob3UwNTEzQGdtYWlsLmNvbVgEAAAAcQ~~ )
#
# CVS Logo ( https://click.e.care.cvs.com/f/a/l4p0zS_3EdPJbgnVLTFuXg~~/AAQRxQA~/RgRnA_uJP0QUaHR0cHM6Ly9jYXJlLmN2cy5jb21XA3NwY0IKZSCJdiFlRfq-rVIXZXJpY2J6aG91MDUxM0BnbWFpbC5jb21YBAAAAHE~ )  CVS Pharmacy, Inc.
# One CVS Drive, Woonsocket, RI 02895   www.care.cvs.com
# ( https://click.e.care.cvs.com/f/a/l4p0zS_3EdPJbgnVLTFuXg~~/AAQRxQA~/RgRnA_uJP0QUaHR0cHM6Ly9jYXJlLmN2cy5jb21XA3NwY0IKZSCJdiFlRfq-rVIXZXJpY2J6aG91MDUxM0BnbWFpbC5jb21YBAAAAHE~ )           .do-not-reply { color: #262626;
# line-height: 21px; font-size: 14px; margin: 0; padding: 12px 0; }
# .line-height { line-height: 0em; }    .do-not-reply { color:
# #262626; line-height: 21px; font-size: 14px; margin: 0; padding:
# 12px 0; } .superscript { position: relative; top: -0.2em; }
# You’re receiving this email as part of an interaction you had
# with CVS Healthcare Practices or CVS Pharmacy®, MinuteClinic® or
# another part of CVS®. This is an automated message. Please do not
# reply to this message.
#
#
# ©2023 CVS Pharmacy, Inc. All Rights
# Reserved.
# ==================================================
# From: CVS Pharmacy <pharmacy@notification.cvshealth.com>
# To: ericbzhou0513@gmail.com
# Subject: Don’t Forget: Just a Few Steps Left to Manage Prescriptions Online!
# Date: Thu, 5 Oct 2023 20:06:24 +0000
# ==================================================
# From: CVS Pharmacy <pharmacy@notification.cvshealth.com>
# To: ericbzhou0513@gmail.com
# Subject: Just a Few Steps Left to Manage Prescriptions Online and More!
# Date: Wed, 4 Oct 2023 18:03:28 +0000
# ==================================================
# From: CVS Pharmacy <pharmacy@notification.cvshealth.com>
# To: ericbzhou0513@gmail.com
# Subject: Thanks for Visiting CVS! Start Managing Prescriptions Online Now!
# Date: Mon, 2 Oct 2023 14:25:07 +0000
# ==================================================
# From: CVS Pharmacy <info@alerts.cvs.com>
# To: <ericbzhou0513@gmail.com>
# Subject: Your records and more
# Date: Mon, 02 Oct 2023 08:23:10 -0600
#
# Please save or print this email for your personal records. Private and confidential. Intended for patient or caregiver
# only. If you have received this document in error, please notify CVS Pharmacy immediately.
# Please keep this for your records
# https://www.cvs.com/pharmacy
#
# Please keep this for your records
#
# As a thank you
#
# We appreciate you choosing CVS for your vaccination.
#
# Please take &#x24;5 off your next in-store &#x24;20 purchase.
#
# Redeem through December 31, 2023
#
# https://www.cvs.com/vaccine/intake/store/mkt-coupon?seq=4785251381196
# Get Coupon
#
# Hi ERIC,
#
#
# Thanks for choosing CVS Pharmacy®. This email contains a record of your recent vaccination.
#
#
#
# If you’re 18 or older, you can view this and other CVS Pharmacy or MinuteClinic health records in your
# https://www.care.cvs.com/login?CID=EM_H4L_202103_VRO
# health dashboard . To access vaccination records for a minor, you first have to add them to your account by requesting to manage their prescriptions through your
# https://www.cvs.com/pharmacy/
# pharmacy dashboard .
#
#
# https://www.care.cvs.com/login?CID=EM_H4L_202103_VRO
# View Record
#
#
# Vaccine administration record
#
#
# Patient information
#
#
# Last name:
# ZHOU
#
# First name:
# ERIC
#
# Date of birth:
# 05/13/1996
#
# Gender:
# M
#
# Address:
# 45 Hooker St Unit 1
# Allston,
#  MA 02134
#
# Phone:
# (267) 992-4050
#
# Primary care provider (PCP):
#
# PCP address:
#
# ,
#
#
#
# Vaccine administration information
#
#
# Vaccine type:
# Flu (Inactivated)
#
# Vaccine administered:
# FLUZONE QUAD 2023-2024 SYRINGE
#
# Administration date:
# 10/02/2023
#
# Manufacturer:
# SANOFI-PASTEUR
#
# Lot #:
# U8070AA
#
# Expiration date:
# 06/2024
#
# Route:
# IM
#
# Site:
# Left Deltoid
#
# Volume (ml):
# 0.5ml
#
# Vaccine Information Statement version date:
# 08/06/2021
#
# Date Vaccine Information Statement given to
# patient:
# 10/02/2023
#
# Verifying pharmacist:
# Baskir, Lauren
# Signature electronically
#  captured
#
# Administering immunizer name and title:
# Baskir, Lauren, RPh
#
# Vaccine prescriber:
# JOHN BOGDASARIAN
#
# Vaccine prescriber address:
# 33 ELECTRIC AVE
#  FITCHBURG,
#  MA 014207954
#
#
# Store information
#
#
# Store #:
# 01018
#
# Rx #:
# 1252122
#
# Address:
# 189 WATERTOWN STREET
# WATERTOWN, MA
#  02472
#
# Phone:
# (617) 332-5528
#
# Need a more detailed record?
#
# The summary above and online may not include complete information or serve as proof of vaccination in some states. If your state needs more details, try the following options:
#
#
# 	1. If you signed a vaccination consent form on paper, we gave you a paper copy of your official Vaccine Administration Record
# 	2. If you gave us your primary care provider's information, contact them for a copy
# 	3.
# https://www.cdc.gov/vaccines/programs/iis/contacts-locate-records.html#state
# See if your state has an immunization registry
# 	4. Call CVS Pharmacy
# Report side effects and help keep the vaccine safe
#
#
# The CDC has created a way for you to report how you feel after the COVID-19 vaccination through a smartphone-based tool that uses text messaging and web surveys to check in with you.
#
#
# https://vsafe.cdc.gov
# Sign up for v-safe today
#
# How was your vaccine experience?
#
# Take 1 minute to
# https://survey.medallia.com/?cvs-imz-vaccinerecord&storeID=01018&visittype=Store&oppID=8aaff0ddd66e41ae90b604fcd694305e&doseNumber=1&imzType=Flu (Inactivated)
# rate your vaccination experience with CVS Pharmacy  and share your thoughts.
#
#
# Consent for services
#
# CONSENT FOR SERVICES: I have received and read (or had read to me) the Vaccine Information Statement(s), Vaccine Information Fact Sheet(s) and/or Patient Fact Sheet(s) regarding the vaccine(s). I understand the benefits and risks of vaccination. I voluntarily assume full responsibility for any reactions or consequences that may result. I understand that I should remain in the vaccine administration area for 15 minutes, or longer if directed, after the vaccination to be monitored for potential adverse reactions. In the event of side effects, I understand I should call the pharmacy, my doctor, or 911. I certify that the information provided regarding eligibility for the vaccine is accurate and request that the vaccine be given to me or to the person previously named for whom I am authorized
#  to make this request. If I am signing on behalf of another individual (including a minor), I attest that I have the authority to do so. Please note the following must have the consent of a parent or guardian: Patients in Alabama/Nebraska under 19 years old; patients in South Carolina under 16 years old; and patients under 18 years old in all other states. If I am receiving a COVID-19 third dose, I attest that I am eligible for that dose because I am immunocompromised. State of Georgia only: I verify a pharmacist asked for my health history and whether I have had a physical exam within the past year. Health care providers did not identify conditions(s) that would mean I should not receive vaccine(s).
#
#
# AUTHORIZATION TO REQUEST PAYMENT: I authorize CVS Pharmacy® ("CVS®") to release medical information to Medicare, Medicaid or any other third party payer as needed and to request payment of authorized benefits to be made on my behalf to CVS. I certify that the information provided about my Medicare, Medicaid or other coverage is correct.
#
#
# ACCEPTANCE OF FINANCIAL RESPONSIBILITY: Notwithstanding anything previously set forth, I agree that I am responsible for and will promptly pay on demand any and all obligations to CVS Pharmacy including all self-pay balances as well as those charges for services not covered or disallowed by my insurance carrier (For non-COVID-19 vaccines).
#
#
# DISCLOSURE OF RECORDS: I understand that CVS® may be required to or may voluntarily disclose my health information with respect to this vaccine to my healthcare providers, my insurance plan, health systems and hospitals, and/or state or federal registries. I understand that CVS will use and disclose my health information as set forth in the CVS Notice of Privacy Practices (copy is available in-store, online or by requesting a paper copy from the pharmacy). State of California only: I agree to have the California Immunization Registry (CAIR) share my immunization data with health care providers, agencies or schools. State of FL only: Students 18-23 may opt out of the immunization registry by notifying pharmacy prior to administration Vaccine Clinics: If I am receiving a vaccine through a
#  vaccine clinic, I understand that my name, vaccine appointment date and time will be provided to the clinic coordinator.
#
#
# Signature electronically captured
#
# Consent date: 09/30/2023
#
# Screening questions
# Are you sick today? (For example: a cold, fever or acute illness)
#
# NA
#
# Do you have allergies or reactions to any foods, medications, vaccines or latex? (For example: eggs, gelatin, neomycin, thimerosal, etc.) or have you ever had a severe allergic reaction (e.g., anaphylaxis) to something? For example, a reaction for which you were treated with epinephrine or EpiPen®, or for which you had to go to the hospital? If yes, what are you allergic to?
#
# N
#
# Have you ever had a serious reaction after receiving a vaccination? Do you have a history of fainting, particularly with vaccines? Has any physician or other healthcare professional ever cautioned or warned you about receiving certain vaccines or receiving vaccines outside of a medical setting?
#
# N
#
# Have you had a seizure or a brain or other nervous system problem or Guillain Barre?
#
# N
#
# Do you have a bleeding disorder or take blood thinners such as Warfarin/Coumadin?
#
# N
#
# Are you currently pregnant or breastfeeding or is there a chance you could become pregnant during the next month?
#
# N
#
# Pharmacist notes:
#
#
# Private and confidential. Intended for patient or caregiver only. If you have
# received this document in error, please notify CVS Pharmacy immediately.
#
#
# https://www.cvs.com/pharmacy
#
# © 2021 CVS Pharmacy Inc.
# One CVS Drive,
# Woonsocket, RI 02895
#
# You are receiving this email to confirm the action noted above. Your
# email address will not be saved or used for any other purposes, unless you chose
# to sign up for special email offers when you registered. You can change your email
# preference in the
# https://www.cvs.com/pharmacy/manage/ice_notification_settings.jsp
# Message
# Settings  at any time. We value your privacy and NEVER give or sell any
# specific information about you to any manufacturer or direct marketers.
#
#
# Privacy and the security of personal information are very
# important to us. If you have questions or concerns about how we protect your
# privacy and the privacy of others, read our site
# https://www.cvs.com/help/privacy_policy.jsp
# Privacy Policy  and our
# https://www.cvs.com/content/patient-privacy
# Patient Privacy Policy .
#
#
#
#
# ==================================================
# From: CVS Pharmacy <info@alerts.cvs.com>
# To: <ericbzhou0513@gmail.com>
# Subject: Your vaccine appointment is confirmed
# Date: Sat, 30 Sep 2023 17:41:01 -0600
# Your appointment details
# https://www.cvs.com/pharmacy
#
# Your appointment details
#
# Hi Eric,
#
#
# We're confirming your Flu vaccine(s).
#
#
#
# Please save or print this message for your records because it contains important information about your appointments, and what to do if your plans change.
#
#
# Vaccine(s):
# Flu
#
# When:
# 10/02/2023
# at 10:30 AM EDT
#
# https://www.cvs.com/addToCalendar?apptDate=10/02/2023&apptTime=10:30 AM EDT&location=189 WATERTOWN ST. ,WATERTOWN,MA 02472&encryptedImzRegistrationID=NPlbp2nEe0WpAhevH%2F9hswLMKiqWffryH6oGhdZnUh4&#61;&isCovid=true&opportunityID=acd65e0f32b44e8eb28d3016896df557&campaignID=80
# Add to calendar
# https://www.cvs.com/vaccine/review-appointments?key=registration&value=NPlbp2nEe0WpAhevH%2F9hswLMKiqWffryH6oGhdZnUh4&#61;&opportunityID=acd65e0f32b44e8eb28d3016896df557&campaignID=80
# Change / cancel appointment
# Where:
#
#
# 189 WATERTOWN ST.
#
# WATERTOWN, MA 02472
#
#
# https://www.google.com/maps/dir/?api=1&destination=189 WATERTOWN ST.++WATERTOWN+MA+02472
# Get directions
#
# On the day of your appointment:
# 	- Please arrive 5 to 10 minutes before your scheduled appointment to check in. Arriving late for your appointment may result in an extended wait time
# 	- Don’t forget your ID and insurance card, voucher or other coverage
# 	- When you arrive, please check in at the CVS Pharmacy counter or follow the signs for the vaccinations
# CVS tips for vaccine shots:
# 	- Wearing short sleeves makes getting a shot easier and faster
# 	- If you must wear long sleeves, dress in layers with the short sleeves underneath
# 	- The CDC recommends drinking plenty of fluids to help relieve possible side effects
# 	- Review more information for the following vaccine(s):
#
# 	-
# https://www.cvs.com/vaccine/view-vaccine-info/FLU_33332032303_en
# Flu
# What to do if you feel sick or have COVID-19 symptoms:
# 	- Contact your health care provider immediately
# 	- If your provider recommends it,
# https://www.cvs.com/minuteclinic/covid-19-testing
# get tested for COVID-19
# 	-
# https://www.cvs.com/vaccine/review-appointments?key=registration&value=NPlbp2nEe0WpAhevH%2F9hswLMKiqWffryH6oGhdZnUh4&#61;&opportunityID=acd65e0f32b44e8eb28d3016896df557&campaignID=80
# Change / cancel your appointment(s)
# 	- Don't come to the pharmacy
# 	- Schedule a new appointment when you're well
# What do you think?
#
# Thanks for scheduling your vaccine with us. We'd love to know how it went. By taking our short survey, you'll help us make booking appointments a better experience for everyone we serve.
#
#
# https://survey.medallia.com/?cvs-imz-apptconfirm&storeID=01018&visittype=Store&oppID=acd65e0f32b44e8eb28d3016896df557&doseNumber=2&imzType=NON_COVID
# Take the survey
#
# https://www.cvs.com/pharmacy
#
#
# © 2021 CVS Pharmacy Inc.
# One CVS Drive,
# Woonsocket, RI 02895
#
#
#
# You are receiving this email to confirm the action noted above. Your
# email address will not be saved or used for any other purposes, unless you chose
# to sign up for special email offers when you registered. You can change your email
# preference in the
# https://www.cvs.com/pharmacy/manage/ice_notification_settings.jsp
# Message
# Settings  at any time. We value your privacy and NEVER give or sell any
# specific information about you to any manufacturer or direct marketers.
#
# Privacy and the security of personal information are very
# important to us. If you have questions or concerns about how we protect your
# privacy and the privacy of others, read our site
# https://www.cvs.com/help/privacy_policy.jsp
# Privacy Policy  and our
# https://www.cvs.com/content/patient-privacy
# Patient Privacy Policy .
#
#
#
#
# ==================================================

# %% [markdown]
# # Usesful Claude system prompt snippets
#
# The assistant is Claude, created by Anthropic. The current date is {}. Claude’s knowledge base was last updated on April 2024. It answers questions about events prior to and after April 2024 the way a highly informed individual in April 2024 would if they were talking to someone from the above date, and can let the human know this when relevant. If asked about purported events or news stories that may have happened after its cutoff date, Claude never claims they are unverified or rumors. It just informs the human about its cutoff date. Claude cannot open URLs, links, or videos. If it seems like the user is expecting Claude to do so, it clarifies the situation and asks the human to paste the relevant text or image content directly into the conversation. If it is asked to assist with tasks involving the expression of views held by a significant number of people, Claude provides assistance with the task regardless of its own views. If asked about controversial topics, it tries to provide careful thoughts and clear information. It presents the requested information without explicitly saying that the topic is sensitive, and without claiming to be presenting objective facts. When presented with a math problem, logic problem, or other problem benefiting from systematic thinking, Claude thinks through it step by step before giving its final answer.
#
# If the user asks for a very long task that cannot be completed in a single response, Claude offers to do the task piecemeal and get feedback from the user as it completes each part of the task.
#
# Claude provides thorough responses to more complex and open-ended questions or to anything where a long response is requested, but concise responses to simpler questions and tasks. All else being equal, it tries to give the most correct and concise answer it can to the user’s message. Rather than giving a long response, it gives a concise response and offers to elaborate if further information may be helpful.
#
# Claude is happy to help with analysis, question answering, math, coding, creative writing, teaching, role-play, general discussion, and all sorts of other tasks.
#
# Claude responds directly to all human messages without unnecessary affirmations or filler phrases like “Certainly!”, “Of course!”, “Absolutely!”, “Great!”, “Sure!”, etc. Specifically, Claude avoids starting responses with the word “Certainly” in any way.

# %% [markdown]
# # Gmail advanced search query
#
# https://support.google.com/mail/answer/7190

# %%
user_proxy = autogen.UserProxyAgent(
    name="Admin",
    system_message="A human admin. Provides filtering criteria for the email search agent.",
    code_execution_config=False,
)

email_search = autogen.AssistantAgent(
    name="Email Search Agent",
    llm_config=llm_config,
    system_message="""
        An agent that searches for emails based on the user's criteria.
        The user can specify the sender, subject, and other criteria to search for emails.
        The agent will then search for emails that match the criteria and return the results to the user.
        The user can then read the emails and take further action if needed.
    """,
)
